# %%
import tensorflow.keras.layers as KL
import tensorflow.keras.backend as KB

# %%
# %pylab inline

import mxnet as mx
mx.npx.set_np()


xx = mx.np.random.rand(1,1,256,256)
pool_size = 64
yy = mx.npx.pooling(xx,kernel=(pool_size,pool_size),stride=(pool_size,pool_size))
yy = mx.nd.UpSampling(yy.as_nd_ndarray(), scale=pool_size, sample_type='nearest')

xx =xx.asnumpy()
yy = yy.asnumpy()

fig = figure(figsize=(12,6))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.imshow(xx[0,0])
ax2.imshow(yy[0,0])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import tensorflow.keras.layers as KL
import tensorflow.keras.backend as KB
# %pylab inline

xx = KB.random_normal(shape=(1, 256, 256, 1))
# xx = mx.np.random.rand(1,1,256,256)
p_size = 64
yy = KL.MaxPooling2D(pool_size=(p_size, p_size), strides=(p_size, p_size))(xx)
# yy = mx.npx.pooling(xx,kernel=(pool_size,pool_size),stride=(pool_size,pool_size))
# yy = mx.nd.UpSampling(yy.as_nd_ndarray(), scale=pool_size, sample_type='nearest')
yy = KL.UpSampling2D(size=(p_size, p_size), interpolation="nearest")(yy)

xx =xx.numpy()
yy = yy.numpy()

fig = figure(figsize=(12,6))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

print(xx.shape)
print(yy.shape)

ax1.imshow(xx[0, :, :, 0])
ax2.imshow(yy[0, :, :, 0])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (1, 256, 256, 1)
# (1, 256, 256, 1)

# %%
yy = KL.MaxPooling2D(pool_size=(p_size, p_size), strides=(p_size, p_size))(xx)
